# %%
import pandas as pd
import numpy as np

# %%
esg_df = pd.read_csv('/A UN Equity.csv', index_col= 0 )

# %%
esg_df
# Out:
#     Year  ESG Disclosure Score  Environmental Disclosure Score  \
# 0   2000                   NaN                             NaN
# 1   2001                   NaN                             NaN
# 2   2002                   NaN                             NaN
# 3   2003                   NaN                             NaN
# 4   2004                   NaN                             NaN
# 5   2005                   NaN                             NaN
# 6   2006               41.3223                         34.8837
# 7   2007               50.0000                         47.2868
# 8   2008               47.5207                         42.6357
# 9   2009               42.5620                         35.6589
# 10  2010               43.8017                         33.3333
# 11  2011               49.1736                         39.5349
# 12  2012               54.5455                         51.1628
# 13  2013               54.5455                         47.2868
# ...

# %%
[i for i in esg_df.columns]
# Out:
# ['Year',
#  'ESG Disclosure Score',
#  'Environmental Disclosure Score',
#  'Direct CO2 Emissions',
#  'Total CO2 Emissions',
#  'CO2 Intensity per Energy',
#  'Total GHG Emissions',
#  'NOx Emissions',
#  'Total Energy Consumption',
#  'Total Water Use',
#  'Hazardous Waste',
#  'Total Wasts',
#  'Environmental Fines #',
#  'Environmental Fines $',
#  'Social Disclosure Score',
#  'Number of Employees',
#  '% Women in Workforce',
#  '% Women in Mgt',
#  'Workforce Accidents',
#  'Fatalities - Employees',
#  'Community Spending',
#  'Governance Disclosure Score',
#  'Size of Board',
#  'Indep Directors',
#  '% Indep Directors',
#  'Board Duration (Years)',
#  '# Board Meetings',
#  'Board Mtg Attendance',
#  'Political Donations']
